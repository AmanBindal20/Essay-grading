# %%
import os
import glob
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\Aman\\Desktop\\essay grading'

# %%
# reading csv files
data1 = pd.read_csv('readabilityAllSets.csv')
data2 = pd.read_csv('CoherenceFeaturesAllSets.csv')
data3 = pd.read_csv('pos_dataframe.csv')
#data3.drop(data3.index[1783:],0,inplace=True)
# using merge function by setting how='outer'
output4 = pd.merge(data1, data2)
output5 = pd.merge(output4,data3,how='outer')

# %%
output5.head()
# Out:
#    essay_set                                              essay  \
# 0          1  Dear local newspaper, I think effects computer...
# 1          1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2          1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3          1  Dear Local Newspaper, @CAPS1 I have found that...
# 4          1  Dear @LOCATION1, I know having computers has a...
#
#    domain1_score  num_of_chars  num_of_words  num_of_long_words  \
# 0              8        1875.0         350.0               13.0
# 1              9        2288.0         423.0               29.0
# 2              7        1541.0         283.0               19.0
# 3             10        3165.0         530.0               55.0
# 4              8        2569.0         473.0               36.0
#
#    num_of_short_words  most_frequent_word_length  average_word_length  \
# 0               151.0                        2.0             4.357143
# ...

# %%
output5.to_csv ('AllFeaturesAllSets.csv', index = False, header=True)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-fbc3c6366e1e> in <module>
# ----> 1 output4.drop(dataframe.index[1783:],0,inplace=True)
#
# NameError: name 'dataframe' is not defined
