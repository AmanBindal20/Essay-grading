# %%
from rake_nltk import Rake
f = open('sample.txt','r')
r = Rake(max_length=1) # Uses stopwords for english from NLTK, and all puntuation characters.

r.extract_keywords_from_text(f.read())

ini = r.get_ranked_phrases()
ini
# Out:
# ['yet',
#  'years',
#  'writing',
#  'writer',
#  'wire',
#  'westeros',
#  'tough',
#  'thrones',
#  'though',
#  'thing',
#  'thick',
#  'tempt',
#  'television',
#  'taken',
#  'swords',
#  'surprise',
#  'surface',
#  'suggest',
#  'suddenly',
#  'success',
#  'story',
#  'start',
#  'sopranos',
#  'song',
#  'someone',
#  'show',
#  'shortcuts',
#  'sets',
#  'set',
#  'serious',
#  'series',
#  'seldom',
#  'seems',
#  'scratches',
#  'sagas',
#  'recently',
#  'reading',
#  'read',
#  'plus',
#  'playing',
#  'people',
#  'packed',
#  'oz',
#  'network',
#  'nearly',
#  'much',
#  'movies',
#  'money',
#  'miles',
#  'mentioned',
#  'martin',
#  'make',
#  'loud',
#  'lot',
#  'looking',
#  'look',
#  'list',
#  'lead',
#  'land',
#  'knights',
#  'kind',
#  'invent',
#  'intrigue',
#  'imagine',
#  'images',
#  'illustrate',
#  'ice',
#  'hopefully',
#  'history',
#  'heck',
#  'hbo',
#  'happens',
#  'happenings',
#  'got',
#  'good',
#  'given',
#  'ghosts',
#  'genre',
#  'geeky',
#  'game',
#  'follow',
#  'fire',
#  'fantasy',
#  'fact',
#  'excitement',
#  'even',
#  'estimates',
#  'end',
#  'eat',
#  'easy',
#  'dragons',
#  'dozens',
#  'dothraki',
#  'done',
#  'dog',
#  'dialogue',
#  'depict',
#  'deceit',
#  'deadwood',
#  'crowns',
#  'credited',
#  'contagious',
#  'confidence',
#  'compelling',
#  'cliffhangers',
#  'characters',
#  'chapter',
#  'cast',
#  'called',
#  'budget',
#  'brought',
#  'brothers',
#  'breaking',
#  'books',
#  'book',
#  'blog',
#  'better',
#  'behind',
#  'beginning',
#  'befitting',
#  'based',
#  'band',
#  'angles',
#  'along',
#  'acerbic',
#  '7',
#  '6',
#  '5',
#  '4',
#  '3',
#  '2',
#  '1']

# %%
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
from nltk.corpus import wordnet
lemmatizer = WordNetLemmatizer()
fin = set()
for word in ini:
    syns = wordnet.synsets(lemmatizer.lemmatize(word))
    if len(syns) != 0:
        syn = syns[0]
        lemmas = syn.lemmas()
        for lemma in lemmas:
            fin.add(lemma.name())
fin
# Out:
# {'1',
#  '12',
#  '2',
#  '3',
#  '4',
#  '5',
#  '6',
#  '7',
#  'Canis_familiaris',
#  'Captain_Hicks',
#  'Crown',
#  'I',
#  'II',
#  'III',
#  'IV',
#  'Little_Joe',
#  'Little_Phoebe',
#  'Martin',
#  'Phoebe',
#  'St._Martin',
#  'TV',
#  'V',
#  'VI',
#  'VII',
#  'XII',
#  'about',
#  'abrasion',
#  'ace',
#  'acerb',
#  'acerbic',
#  'acquire',
#  'advert',
#  'advise',
#  'all_of_a_sudden',
#  'allure',
#  'almost',
#  'along',
#  'angle',
#  'appear',
#  'approximation',
#  'arse',
#  'aspect',
#  'ass',
#  'asset',
#  'assurance',
#  'astringent',
#  'author',
#  'authority',
#  'authorship',
#  'backside',
#  'band',
#  'base',
#  'batch',
#  'befit',
#  'beginning',
#  'behind',
#  'beseem',
#  'better',
#  'blade',
#  'blog',
#  'blood_brother',
#  'book',
#  'bottom',
#  'brand',
#  'break',
#  'breakage',
#  'breaking',
#  'bring',
#  'bring_up',
#  'brother',
#  'budget',
#  'bum',
#  'buns',
#  'butt',
#  'buttocks',
#  'call',
#  'can',
#  'cast',
#  'cast_of_characters',
#  'chapter',
#  'character',
#  'cinque',
#  'circle',
#  'cite',
#  'cliffhanger',
#  'come_about',
#  'compel',
#  'composition',
#  'conceive_of',
#  'confidence',
#  'contagious',
#  'contrive',
#  'convey',
#  'credit',
#  'crosscut',
#  'cutoff',
#  'deadwood',
#  'deal',
#  'deceit',
#  'depict',
#  'derriere',
#  'deuce',
#  'deuce-ace',
#  'devise',
#  'dialog',
#  'dialogue',
#  'do',
#  'dog',
#  'domestic_dog',
#  'dozen',
#  'dragon',
#  'dramatis_personae',
#  'duologue',
#  'easy',
#  'eat',
#  'end',
#  'envisage',
#  'establish',
#  'estimate',
#  'estimation',
#  'eve',
#  'even',
#  'evening',
#  'eventide',
#  'excitement',
#  'excogitate',
#  'excoriation',
#  'exemplify',
#  'exhilaration',
#  'expression',
#  'face',
#  'facial_expression',
#  'fact',
#  'fall_out',
#  'fanny',
#  'fantasy',
#  'fictional_character',
#  'fictitious_character',
#  'film',
#  'fin',
#  'fire',
#  'firedrake',
#  'five',
#  'fivesome',
#  'flick',
#  'flock',
#  'follow',
#  'forge',
#  'form',
#  'formulate',
#  'found',
#  'four',
#  'foursome',
#  'fraudulence',
#  'fundament',
#  'game',
#  'genre',
#  'get',
#  'ghost',
#  'given',
#  'go_on',
#  'good',
#  'good_deal',
#  'great_deal',
#  'ground',
#  'half_a_dozen',
#  'hap',
#  'happen',
#  'happening',
#  'hatful',
#  'heap',
#  'heptad',
#  'hexad',
#  'hind_end',
#  'hindquarters',
#  'history',
#  'hopefully',
#  'ice',
#  'idea',
#  'ideate',
#  'illustrate',
#  'image',
#  'imagine',
#  'individual',
#  'instance',
#  'international_mile',
#  'intrigue',
#  'invent',
#  'keister',
#  'kind',
#  'knight',
#  'land',
#  'land_mile',
#  'late',
#  'lately',
#  'latterly',
#  'lead',
#  'leash',
#  'list',
#  'listing',
#  'look',
#  'looking',
#  'looking_at',
#  'lot',
#  'loud',
#  'machination',
#  'make',
#  'mass',
#  'mental_image',
#  'mention',
#  'mess',
#  'mi',
#  'mickle',
#  'midst',
#  'mile',
#  'mint',
#  'money',
#  'mortal',
#  'most',
#  'motion-picture_show',
#  'motion_picture',
#  'mountain',
#  'movie',
#  'moving-picture_show',
#  'moving_picture',
#  'much',
#  'muckle',
#  'name',
#  'narration',
#  'narrative',
#  'nates',
#  'natural_event',
#  'near',
#  'nearly',
#  'network',
#  'nigh',
#  'obligate',
#  'oblige',
#  'occur',
#  'occurrence',
#  'occurrent',
#  'of_a_sudden',
#  'of_late',
#  'on',
#  'one',
#  'pack',
#  'pass',
#  'pass_off',
#  'passel',
#  'peck',
#  'penning',
#  'pentad',
#  'people',
#  'person',
#  'phantasy',
#  'pic',
#  'picture',
#  'picture_show',
#  'pile',
#  'playing',
#  'plenty',
#  'plus',
#  'posterior',
#  'pot',
#  'prat',
#  'precondition',
#  'presumption',
#  'propose',
#  'quadruplet',
#  'quartet',
#  'quatern',
#  'quaternary',
#  'quaternion',
#  'quaternity',
#  'quint',
#  'quintet',
#  'quintuplet',
#  'quite_a_little',
#  'raft',
#  'rarely',
#  'read',
#  'reading',
#  'rear',
#  'rear_end',
#  'recently',
#  'refer',
#  'render',
#  'rump',
#  'saga',
#  'scrape',
#  'scratch',
#  'seat',
#  'seem',
#  'seldom',
#  'self-assurance',
#  'self-confidence',
#  'septenary',
#  'septet',
#  'series',
#  'serious',
#  'sestet',
#  'set',
#  'seven',
#  'sevener',
#  'sextet',
#  'sextuplet',
#  'shade',
#  'shortcut',
#  'show',
#  'sight',
#  'single',
#  'sise',
#  'six',
#  'sixer',
#  'slew',
#  'somebody',
#  'someone',
#  'song',
#  'soprano',
#  'sort',
#  'soul',
#  'spate',
#  'specter',
#  'spectre',
#  'spook',
#  'stack',
#  'start',
#  'stat_mi',
#  'statute_mile',
#  'steel',
#  'stern',
#  'story',
#  'street_fighter',
#  'success',
#  'suddenly',
#  'suggest',
#  'suit',
#  'sureness',
#  'surface',
#  'surprise',
#  'sword',
#  'tail',
#  'tail_end',
#  'take',
#  'take_place',
#  'tale',
#  'telecasting',
#  'television',
#  'tempt',
#  'tercet',
#  'terminal',
#  'ternary',
#  'ternion',
#  'terzetto',
#  'tetrad',
#  'thick',
#  'thing',
#  'though',
#  'three',
#  'threesome',
#  'throne',
#  'tidy_sum',
#  'tierce',
#  'tooshie',
#  'tough',
#  'trey',
#  'triad',
#  'trine',
#  'trinity',
#  'trio',
#  'triplet',
#  'troika',
#  'tush',
#  'twelve',
#  'twelvemonth',
#  'two',
#  'unity',
#  'variety',
#  'video',
#  'virtually',
#  'vocal',
#  'wad',
#  'water_ice',
#  'web',
#  'web_log',
#  'well-nigh',
#  'wire',
#  'wraith',
#  'writer',
#  'writing',
#  'year',
#  'yet',
#  'yr'}

# %%
 'video' in fin
# Out:
# True

# %%
f2 = open('sample2.txt','r')
r.extract_keywords_from_text(f2.read())
ini = r.get_ranked_phrases()
print(ini)
tot = 0
for word in ini:
    if lemmatizer.lemmatize(word) in fin:
        tot+=1
        print(lemmatizer.lemmatize(word))
tot
# Out:
# ['yet', 'writing', 'wholeheartedly', 'whether', 'top', 'thrones', 'storytelling', 'show', 'sexualism', 'series', 'see', 'sad', 'reastic', 'profanity', 'people', 'outstanding', 'one', 'nudity', 'news', 'movies', 'morbid', 'medieval', 'maybe', 'made', 'love', 'lost', 'least', 'kept', 'impeccable', 'hate', 'guessing', 'grim', 'good', 'glued', 'general', 'game', 'frankly', 'find', 'fantasy', 'falls', 'exception', 'evil', 'even', 'episode', 'end', 'elements', 'easy', 'done', 'dies', 'defend', 'cheer', 'changes', 'carrying', 'capable', 'brutal', 'bouts', 'board', 'better', 'beginning', 'approve', 'applaud', 'amazing', 'also', 'acting']
# yet
# writing
# throne
# show
# series
# people
# one
# movie
# good
# game
# fantasy
# even
# end
# easy
# better
# beginning
# 16
