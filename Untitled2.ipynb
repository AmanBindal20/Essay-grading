# %%
from pytrends.request import TrendReq

pytrends = TrendReq(hl='en-US', tz=360)

# %%
kw_list = ['Pizza', 'Italian', 'Spaghetti', 'Breadsticks', 'Sausage']
pytrends.build_payload(kw_list, cat=0, timeframe='today 5-y', geo='', gprop='')

# %%
pytrends.interest_over_time()
# Out:
#             Pizza  Italian  Spaghetti  Breadsticks  Sausage isPartial
# date
# 2016-04-10     73       15          4            0        3     False
# 2016-04-17     72       14          4            0        3     False
# 2016-04-24     75       14          4            0        3     False
# 2016-05-01     73       15          4            0        3     False
# 2016-05-08     73       15          4            0        3     False
# ...           ...      ...        ...          ...      ...       ...
# 2021-02-28     75       13          5            0        4     False
# 2021-03-07     75       13          5            0        4     False
# 2021-03-14     79       14          5            0        4     False
# 2021-03-21     80       14          5            0        4     False
# 2021-03-28     80       13          5            0        4      True
#
# [260 rows x 6 columns]
